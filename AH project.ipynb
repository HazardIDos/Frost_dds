# %%
def list_item():
   name= input("Enter the item name:\n")
   print(f"Item Name: {name}")
   return name

def place_bid(current_bid, new_bid):
    try:
        new_bid = float(input("Enter your bid Dollar amount:\n"))
        if new_bid > current_bid:
            return new_bid
        else:print("Bid must be higher than current bid.")
        return current_bid
    except ValueError:
        print("Invalid bid Dollar amount.")
    return current_bid
def close_auction(final_bid):
    print(f"Auction closed at ${final_bid:.2f}, Winner! thank you for participating!")


item = list_item()
current_bid = 0.0
while True:
    current_bid = place_bid (current_bid, 0)
    more = input("Do you wanna Gamba more money? (yay/nay) \n")
    if more != 'yay':
        break
close_auction(current_bid)
# Out:
# Enter the item name:
# Teddy Bear
# Item Name: Teddy Bear
# Enter your bid Dollar amount:
# 90
# Do you wanna Gamba more money? (yay/nay)
# yay
# Enter your bid Dollar amount:
# 10000
# Do you wanna Gamba more money? (yay/nay)
# yay
# Enter your bid Dollar amount:
# 2000000
# Do you wanna Gamba more money? (yay/nay)
# nay
# Auction closed at $2000000.00, thank you for participating!
